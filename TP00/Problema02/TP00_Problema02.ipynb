# %% [markdown]
# ####
# Problema 1: Evaluar en papel y lápiz y luego verificar en Python las siguientes expresiones:
# a) Discutir el resultado de las siguientes operaciones: 6/2(2+1) y 6÷2(2+1) y 8 : 2(2+2) y verificarlas
# con la cabeza, con calculadora y Python.

# %%
ejer1 = 6/2*(2+1)
ejer1
# Out:
# 9.0

# %%
ejer2 = 6/2*(2+1)
ejer2
# Out:
# 9.0

# %% [markdown]
# ejer3  = 8:2(2+2)
# ejer3

# %% [markdown]
# ####
# Problema 2: Dada la matriz:
# a = array([[0, 1, 5], [3, 4, -9], [-1, 6, 7]]),

# %%
import numpy as npy
a = npy.array([[0, 1, 5], [3, 4, -9], [-1, 6, 7]])
b = a[1,1]
c = a[0,:]
d = a[0:2,1]
e = a[1:3,0:2]
f = e[:,1]

print("array:", a)

print("a[1,1]=",b)

print("a[0,:]=", c)

print("a[0:2,1]=",d)

print("a[1:3,0:2]=", e)

print("e[:,1]=", f)
# Out:
# array: [[ 0  1  5]
#  [ 3  4 -9]
#  [-1  6  7]]
# a[1,1]= 4
# a[0,:]= [0 1 5]
# a[0:2,1]= [1 4]
# a[1:3,0:2]= [[ 3  4]
#  [-1  6]]
# e[:,1]= [4 6]

# %% [markdown]
# ####
# Problema 3: Dados los vectores a = array([-2, 3, 6]) y b = array([0, -1, 5]) calcular con papel
# y lapiz:
# a) f = a − b^2
# b) t = a − 2b
# c) z = 4a + 3b

# %%
a = npy.array([-2, 3, 6])
b = npy.array([0, -1, 5])

f = a - b**2
t = a - 2*b
z = 4*a + 3*b

print(f)
print(t)
print(z)
# Out:
# [ -2   2 -19]
# [-2  5 -4]
# [-8  9 39]

# %% [markdown]
# ####
# Problema 4: Graficar las siguientes funciones con python usando numpy y matplotlib:
# a) y = 5 sin(2x) con x : −10 < x < 10.
# b) y = 3 log(x2).

# %%
import numpy as npy
import matplotlib.pyplot as plot

##
x = npy.arange(-10, 11, 0.1)
y = y = 5*npy.sin(2*x) 

fig, ax = plot.subplots(figsize=(16, 6))
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Gráfico de la Función')
ax.grid()
ax.plot(x,y, label= "y = 5*npy.sin(2*x)")
ax.legend()

# %%
x = npy.arange(0, 11, 0.2)
y = y = 3*npy.log(x*2) 

fig, ax = plot.subplots(figsize=(16, 6))
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Gráfico de la funcion')
ax.grid()
ax.plot(x,y, 'r-', label = "y = 3*npy.log(x*2)")
ax.legend()
# Out:
# /tmp/ipykernel_10571/3362713638.py:2: RuntimeWarning: divide by zero encountered in log
#   y = y = 3*npy.log(x*2)

# %% [markdown]
# ####
# Problema 5: Graficar las siguientes funciones con python:
# a) En un mismo gr ́afico, sobreponer las siguientes funciones incluyendo su leyenda, ejes, t ́ıtulo, y
# usando distintos estilos de trazado.
# Considere el rango de valores para x : 0 < x < 20 con 1000 puntos en este intervalo.
# y1 = cos(x)
# y2 = sin(x)
# y3 = cos(2x)
# y4 = sin(x/2)

# %%
x = npy.linspace(0, 20, 1000)

y1 = npy.cos(x)
y2 = npy.sin(x)
y3 = npy.cos(2*x)
y4 = npy.sin(x/2)

fig, ax = plot.subplots(figsize=(16, 6))
ax.set_xlabel('Angulo')
ax.set_ylabel('Valor de la función')
ax.set_title('Funciones trigonométricas')
ax.grid()
ax.plot(x, y1,'r-',label="Cos(x)")
ax.plot(x, y2, 'b-',label="Sen(x)")
ax.plot(x, y3, 'r--',label="Cos(2x)")
ax.plot(x, y4, 'b--', label="Sen(x/2)")
ax.legend()

# %% [markdown]
# b) En una misma figura, realizar 4 graficos (separados), usando la funci ́on subplot con las siguientes
# funciones. En cada gr ́afico incluir r ́otulo de los ejes, t ́ıtulo y grilla.
# Considere el rango de valores para x : −5,0 < x < 5,0 con 500 puntos en este intervalo.
# y1 = − sin(x) cos(x2)
# y2 = sin2(x) cos2(x2)
# y3 = exp(−x/4) sin(x)
# y4 = exp(−x/2) sin2(x)

# %%
import numpy as npy
import matplotlib.pyplot as plt

x = npy.linspace(-5, 5, 500)

y1 = -npy.sin(x)*npy.cos(x**2)
y2 = (npy.sin(x))**2*(npy.cos(x**2))**2
y3 = npy.exp(-x/4)*npy.sin(x)
y4 = npy.exp(-x/2)*npy.sin(x)

fig, ax = plt.subplots(figsize=(16, 6),nrows=2, ncols=2)
ax[0,0].set_xlabel('Angulo')
ax[0,0].set_ylabel('Valor de la función')
#ax[0,0].set_title('Funciones trigonométricas')
ax[0,0].grid()
ax[0,0].plot(x, y1,'r-',label="y1 = −sin(x) cos(x^2)")
ax[0,0].legend()

ax[1,0].set_xlabel('Angulo')
ax[1,0].set_ylabel('Valor de la función')
#ax[1,0].set_title('Funciones trigonométricas')
ax[1,0].grid()
ax[1,0].plot(x, y2, 'b-',label="y2 = npy.sin^2(x)*npy.cos**2(x^2)")
ax[1,0].legend(loc= 'upper left')

ax[0, 1].set_xlabel('Angulo')
ax[0, 1].set_ylabel('Valor de la función')
#ax[0, 1].set_title('Funciones trigonométricas')
ax[0, 1].grid()
ax[0, 1].plot(x, y3, 'g-',label="y3 = exp(−x/4)*npy.sin(x)")
ax[0, 1].legend()

ax[1, 1].set_xlabel('Angulo')
ax[1, 1].set_ylabel('Valor de la función')
#ax[1, 1].set_title('Funciones trigonométricas')
ax[1, 1].grid()
ax[1, 1].plot(x, y4, 'k-', label="y4 = exp(−x/2)*npy.sin2(x)")
ax[1, 1].legend()

# %% [markdown]
# ####
# Problema 6: Dados los siguientes vectores:
# x 1 = [1, 2, 3, 4, 5] e y 1 = [1,2214, 1,4918, 1,8221, 2,2255, 2,7183].
# x 2 = [1, 2, 3, 4, 5] e y 2 = [3, 9, 19, 33, 51].
# x 3 = [1, 2, 3, 4, 5] e y 3 = [10,0000, 13,4657, 15,4931, 16,9315, 18,0472].
# a) determinar usando python si y i , (i = 1, 2, 3) es una función exponencial, logarı́tmica o potencial.
# Ayuda: realizar gráficos usando diferentes escalas en los ejes.

# %%
x1 = [1, 2, 3, 4, 5]
y1 = [1.2214, 1.4918, 1.8221, 2.2255, 2.7183]

x2 = [1, 2, 3, 4, 5]
y2 = [3, 9, 19, 33, 51]

x3 = [1, 2, 3, 4, 5]
y3 = [10.0000, 13.4657, 15.4931, 16.9315, 18.0472]

fig, ax = plt.subplots(figsize=(18, 10),nrows=2, ncols=2)
ax[0,0].set_xlabel('x1')
ax[0,0].set_ylabel('y1')
ax[0,0].grid()
ax[0,0].plot(x1, y1,'r-')

ax[0,1].set_xlabel('x2')
ax[0,1].set_ylabel('y2')
ax[0,1].grid()
ax[0,1].plot(x2, y2,'b-')

ax[1, 0].set_xlabel('x2')
ax[1, 0].set_ylabel('y2')
ax[1, 0].grid()
ax[1, 0].plot(x2, y2,'k-')

ax[1, 1].plot(0, 0, 'r-', label="x1 = [1, 2, 3, 4, 5] . y1 = [1.2214, 1.4918, 1.8221, 2.2255, 2.7183]")
ax[1, 1].plot(0, 0, 'b-', label="x2 = [1, 2, 3, 4, 5] . y2 = [3, 9, 19, 33, 51]")
ax[1, 1].plot(0, 0, 'k-', label="x3 = [1, 2, 3, 4, 5] . y3 = [10.0000, 13.4657, 15.4931, 16.9315, 18.0472]")
ax[1, 1].legend(loc='center', labelspacing=1.5)
ax[1, 1].get_xaxis().set_visible(False) #ocultar eje x
ax[1, 1].get_yaxis().set_visible(False) #ocultar eje y

# %% [markdown]
# ####
# Problema 7: Graficá el polinomio p(x) = 4x 4 − 5x 2 − 2x en el intervalo −10 < x < 10 con paso 0,1.

# %%
x = npy.arange(-10, 10, 0.1)
px = 4*x**4 - 5*x**2 - 2*x

fig, ax = plt.subplots(figsize=(5, 5))
ax.set_xlabel('x')
ax.set_ylabel('p')
ax.grid()
ax.plot(x, px,'r-', label='p(x) = 4x^4 − 5x^2 − 2x')
ax.legend()

# %% [markdown]
# ####
# Problema 8: Dados los siguientes polinomios:
# a) f1(x) = x^3 − 6x^2 − 12x − 8
# b) f2(x) = x^3 − 8x^2 + 20x − 16
# c) f3(x) = x^3 − 5x^2 − 7x − 3
# d) f4(x) = x − 2
# a) Grafique cada una de las funciones en el intervalo [0,4].

# %%
x = npy.arange(0, 5, 0.1)

f1 = x**3 - 6*x**2 - 12*x - 8
f2 = x**3 - 8*x**2 + 20*x - 16
f3 = x**3 - 5*x**2 - 7*x - 3
f4 = x - 2

fig, ax = plt.subplots(figsize=(16, 6),nrows=2, ncols=2)
#ax[0,0].set_xlabel('x')
ax[0,0].set_ylabel('Valor de la función')
#ax[0,0].set_title('Funciones trigonométricas')
ax[0,0].grid()
ax[0,0].plot(x, f1,'r-',label="f1 = x^3 - 6x^2 - 12x - 8")
ax[0,0].legend()

ax[1,0].set_xlabel('x')
ax[1,0].set_ylabel('Valor de la función')
#ax[1,0].set_title('Funciones trigonométricas')
ax[1,0].grid()
ax[1,0].plot(x, f2, 'b-',label="f2 = x^3 - 8x^2 + 20x - 16")
ax[1,0].legend(loc= 'upper left')

#ax[0, 1].set_xlabel('x')
ax[0, 1].set_ylabel('Valor de la función')
#ax[0, 1].set_title('Funciones trigonométricas')
ax[0, 1].grid()
ax[0, 1].plot(x, f3, 'g-',label="f3 = x^3 - 5x^2 - 7x - 3")
ax[0, 1].legend()

ax[1, 1].set_xlabel('x')
ax[1, 1].set_ylabel('Valor de la función')
#ax[1, 1].set_title('Funciones trigonométricas')
ax[1, 1].grid()
ax[1, 1].plot(x, f4, 'k-', label="f4 = x - 2")
ax[1, 1].legend()

# %% [markdown]
# b) Use funciones y clases de la librerı́a numpy de python con vectores de coeficientes de polinomios para
# evaluar las combinaciones lineales:
# a) f1(x) − 2*f3(x)
# b) 3*f4(x) − f1(x) − 2*f2(x)

# %%
#esto no es lo que se pide
f13=f1-2*f3
f412=3*f4 - f1 - 2*f2

fig, ax = plt.subplots(figsize=(16, 6),nrows=1, ncols=2)
ax[0].set_xlabel('x')
ax[0].set_ylabel('Valor de la función')
#ax[0].set_title('Funciones trigonométricas')
ax[0].grid()
ax[0].plot(x, f13,'r-',label="f13 = f1-2*f3")
ax[0].legend()

ax[1].set_xlabel('x')
ax[1].set_ylabel('Valor de la función')
#ax[1].set_title('Funciones trigonométricas')
ax[1].grid()
ax[1].plot(x, f412, 'b-',label="f412 = 3*f4 - f1 - 2*f2")
ax[1].legend(loc= 'upper left')

# %% [markdown]
# Los polinomios a evaluar:
# a) f1(x) = x^3 − 6x^2 − 12x − 8
# b) f2(x) = x^3 − 8x^2 + 20x − 16
# c) f3(x) = x^3 − 5x^2 − 7x − 3
# d) f4(x) = x − 2

# %%
from numpy.polynomial.polynomial import polyval as pval
coeff1=[-8, -12, -6, 1]
coeff2=[-16, 20, -8, 1]
coeff3=[-3, -7, -5, 1]
coeff4=[-2, 1]

#evaluando en 0
print(pval(0, coeff1))
print(pval(0, coeff2))
print(pval(0, coeff3))
print(pval(0, coeff4))
# Out:
# -8.0
# -16.0
# -3.0
# -2.0

# %%
#evaluando en 1
print(pval(1, coeff1))
print(pval(1, coeff2))
print(pval(1, coeff3))
print(pval(1, coeff4))
# Out:
# -25.0
# -3.0
# -14.0
# -1.0

# %% [markdown]
# ####
# Problema 9: Determine las raı́ces de los siguientes polinomios (sugerencia: numpy.roots). Luego grafique
# cada polinomio en un intervalo adecuado a fin de verificar dichas raı́ces:
# a) g1 (x) = x^3 − 5x^2 + 2x + 8
# b) g2 (x) = x^2 − 2x + 2
# c) g3 (x) = x^5 − 3x^4 − 11x^3 + 27x^2 + 10x − 24
# d) g4 (x) = x^5 + 3x^4 − 4x^3 − 26x^2 − 40x − 24

# %%
coefg1=[8, 2, -5, 1]
coefg2=[2, -2, 1]
coefg3=[-24, 10, 27, -11, -3, 1]
coefg4=[-24, -40, -26, -4, 3, 1]

print(npy.roots(coefg1))
print(npy.roots(coefg2))
print(npy.roots(coefg3))
print(npy.roots(coefg4))
# Out:
# [-1.    0.5   0.25]
# [0.5+0.5j 0.5-0.5j]
# [-1.          1.         -0.33333333  0.5         0.25      ]
# [-0.5       +0.5j -0.5       -0.5j  0.33333333+0.j  -0.50000001+0.j
#  -0.49999999+0.j ]
